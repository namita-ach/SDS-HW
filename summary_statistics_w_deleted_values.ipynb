# %% [markdown]
# <a href="https://colab.research.google.com/github/namita-ach/SDS-HW/blob/main/summary_statistics_w_deleted_values.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
import pandas as pd
import  numpy as np
import matplotlib.pyplot as plt

# %%
#read the csv
data = pd.read_csv('company_sales_data_w_deleted_values.csv')

# %%
#make the dataframe
df = pd.DataFrame(data)
df
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1        NaN    1500.0      5200.0          NaN   1200.0
# 1              2     2630.0    1200.0      5100.0       6100.0   2100.0
# 2              3        NaN    1340.0      4550.0       9550.0      NaN
# 3              4     3400.0    1130.0         NaN          NaN   1870.0
# 4              5     3600.0    1740.0      4560.0       7760.0   1560.0
# 5              6        NaN       NaN      4890.0       7490.0   1890.0
# 6              7     2980.0    1120.0      4780.0          NaN   1780.0
# 7              8     3700.0    1400.0         NaN       9960.0   2860.0
# 8              9        NaN    1780.0      6100.0       8100.0   2100.0
# 9             10     1990.0    1890.0      8300.0      10300.0      NaN
# 10            11     2340.0    2100.0      7300.0          NaN   2400.0
# 11            12     2900.0    1760.0      7400.0      14400.0   1800.0
#
#     moisturizer  total_units  total_profit
# 0        1500.0          NaN           NaN
# 1        1200.0      18330.0           NaN
# 2        1340.0          NaN      224700.0
# 3           NaN      22270.0           NaN
# 4        1740.0          NaN      209600.0
# 5           NaN      20140.0           NaN
# 6        1120.0      29550.0      295500.0
# 7           NaN      36140.0      361400.0
# 8        1780.0          NaN           NaN
# 9        1890.0      26670.0      266700.0
# 10       2100.0      41280.0      412800.0
# 11       1760.0      30020.0           NaN

# %%
df = pd.DataFrame(data, index=None)
profit_list = df['total_profit'].tolist()
plt.plot(x,profit_list)
plt.xlabel('months')
plt.ylabel('total profit')
plt.show()

# %%
#new copies of the dataframe
df_for_median = df.copy()
df_for_mean = df.copy()

# %%
x = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# %%
#finding the number of parameters = number of columns -1
columns = len(df.axes[1])
print(f"The number of parameters is {columns-1}")
# Out:
# The number of parameters is 8

# %%
#shows us the top of the dataset
df.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1        NaN    1500.0      5200.0          NaN   1200.0
# 1             2     2630.0    1200.0      5100.0       6100.0   2100.0
# 2             3        NaN    1340.0      4550.0       9550.0      NaN
# 3             4     3400.0    1130.0         NaN          NaN   1870.0
# 4             5     3600.0    1740.0      4560.0       7760.0   1560.0
#
#    moisturizer  total_units  total_profit
# 0       1500.0          NaN           NaN
# 1       1200.0      18330.0           NaN
# 2       1340.0          NaN      224700.0
# 3          NaN      22270.0           NaN
# 4       1740.0          NaN      209600.0

# %%
#tells us how much info we have in each field
df.count()
# Out:
# month_number    12
# facecream        8
# facewash        11
# toothpaste      10
# bathingsoap      8
# shampoo         10
# moisturizer      9
# total_units      8
# total_profit     6
# dtype: int64

# %%
#summary about the kind of information we have
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   month_number  12 non-null     int64
#  1   facecream     8 non-null      float64
#  2   facewash      11 non-null     float64
#  3   toothpaste    10 non-null     float64
#  4   bathingsoap   8 non-null      float64
#  5   shampoo       10 non-null     float64
#  6   moisturizer   9 non-null      float64
#  7   total_units   8 non-null      float64
#  8   total_profit  6 non-null      float64
# dtypes: float64(8), int64(1)
# memory usage: 992.0 bytes

# %%
#finding the parameters
for parameter in df.axes[1][1:]:
  print(parameter)
# Out:
# facecream
# facewash
# toothpaste
# bathingsoap
# shampoo
# moisturizer
# total_units
# total_profit

# %% [markdown]
# Replace NaN w/ median:

# %%
def fill_na_with_median(df):
    for column in df.columns:
        median = np.nanmedian(df[column])
        df[column].replace(np.nan, median, inplace=True)
    return df

# %%
median_substitution = fill_na_with_median(df_for_median)
median_substitution
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1     2940.0    1500.0      5200.0       8825.0   1200.0
# 1              2     2630.0    1200.0      5100.0       6100.0   2100.0
# 2              3     2940.0    1340.0      4550.0       9550.0   1880.0
# 3              4     3400.0    1130.0      5150.0       8825.0   1870.0
# 4              5     3600.0    1740.0      4560.0       7760.0   1560.0
# 5              6     2940.0    1500.0      4890.0       7490.0   1890.0
# 6              7     2980.0    1120.0      4780.0       8825.0   1780.0
# 7              8     3700.0    1400.0      5150.0       9960.0   2860.0
# 8              9     2940.0    1780.0      6100.0       8100.0   2100.0
# 9             10     1990.0    1890.0      8300.0      10300.0   1880.0
# 10            11     2340.0    2100.0      7300.0       8825.0   2400.0
# 11            12     2900.0    1760.0      7400.0      14400.0   1800.0
#
#     moisturizer  total_units  total_profit
# 0        1500.0      28110.0      281100.0
# 1        1200.0      18330.0      281100.0
# 2        1340.0      28110.0      224700.0
# 3        1740.0      22270.0      281100.0
# 4        1740.0      28110.0      209600.0
# 5        1740.0      20140.0      281100.0
# 6        1120.0      29550.0      295500.0
# 7        1740.0      36140.0      361400.0
# 8        1780.0      28110.0      281100.0
# 9        1890.0      26670.0      266700.0
# 10       2100.0      41280.0      412800.0
# 11       1760.0      30020.0      281100.0

# %%
profit_list = df_for_median['total_profit'].tolist()
plt.plot(x,profit_list)
plt.xlabel('months')
plt.ylabel('total profit')
plt.show()

# %% [markdown]
# Replace NaN w/ mean:

# %%
def fill_na_with_mean(df):
    for column in df.columns:
        mean = np.nanmean(df[column])
        df[column].replace(np.nan, mean, inplace=True)
    return df

# %%
mean_substitution = fill_na_with_mean(df_for_mean)
mean_substitution
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1     2940.0    1500.0      5200.0       8825.0   1200.0
# 1              2     2630.0    1200.0      5100.0       6100.0   2100.0
# 2              3     2940.0    1340.0      4550.0       9550.0   1880.0
# 3              4     3400.0    1130.0      5150.0       8825.0   1870.0
# 4              5     3600.0    1740.0      4560.0       7760.0   1560.0
# 5              6     2940.0    1500.0      4890.0       7490.0   1890.0
# 6              7     2980.0    1120.0      4780.0       8825.0   1780.0
# 7              8     3700.0    1400.0      5150.0       9960.0   2860.0
# 8              9     2940.0    1780.0      6100.0       8100.0   2100.0
# 9             10     1990.0    1890.0      8300.0      10300.0   1880.0
# 10            11     2340.0    2100.0      7300.0       8825.0   2400.0
# 11            12     2900.0    1760.0      7400.0      14400.0   1800.0
#
#     moisturizer  total_units  total_profit
# 0        1500.0      28110.0      281100.0
# 1        1200.0      18330.0      281100.0
# 2        1340.0      28110.0      224700.0
# 3        1740.0      22270.0      281100.0
# 4        1740.0      28110.0      209600.0
# 5        1740.0      20140.0      281100.0
# 6        1120.0      29550.0      295500.0
# 7        1740.0      36140.0      361400.0
# 8        1780.0      28110.0      281100.0
# 9        1890.0      26670.0      266700.0
# 10       2100.0      41280.0      412800.0
# 11       1760.0      30020.0      281100.0

# %%
df = pd.DataFrame(data, index=None)
profit_list = df_for_mean['total_profit'].tolist()
plt.plot(x,profit_list)
plt.xlabel('months')
plt.ylabel('total profit')
plt.show()
